# %% [markdown]
# **Practice Codes**

# %%
dict1 = {1:"Prathamesh", 2:"Swapnil" , 3:"Sarthak" , 4:"Omkar"}
# del dict1[2]
print(dict1)
dict2 = dict1.copy()
print(dict2)
dict1[5] = "Samadhan"
print(dict1)
print(dict2)
# Out:
# {1: 'Prathamesh', 2: 'Swapnil', 3: 'Sarthak', 4: 'Omkar'}
# {1: 'Prathamesh', 2: 'Swapnil', 3: 'Sarthak', 4: 'Omkar'}
# {1: 'Prathamesh', 2: 'Swapnil', 3: 'Sarthak', 4: 'Omkar', 5: 'Samadhan'}
# {1: 'Prathamesh', 2: 'Swapnil', 3: 'Sarthak', 4: 'Omkar'}
