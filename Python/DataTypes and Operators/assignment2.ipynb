# %% [markdown]
# Day 2 Assignment

# %%
student_name = "Prathamesh Bhagwat"
print(student_name)
print(type(student_name))
print(id(student_name))

student_roll_no= 26
print(student_roll_no)
print(type(student_roll_no))
print(id(student_roll_no))

student_percentage = 87.20
print(student_percentage)
print(type(student_percentage))
print(id(student_percentage))

isPassed = True
print(isPassed)
print(type(isPassed))
print(id(isPassed))

complex = 3+4j
print(complex)
print(type(complex))
print(id(complex))

nothing = None
print(nothing)
print(type(nothing))
print(id(nothing))
# Out:
# Prathamesh Bhagwat
# <class 'str'>
# 1293725983216
# 26
# <class 'int'>
# 140705670481816
# 87.2
# <class 'float'>
# 1293725206224
# True
# <class 'bool'>
# 140705669581568
# (3+4j)
# <class 'complex'>
# 1293725215024
# None
# <class 'NoneType'>
# 140705669581632

# %%
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %%
x="100"
y=50
num = int(x)
res = y + num
print("The result of addition is:", res)
# Out:
# The result of addition is: 150

# %%
a = 10 
b = 20 
print(a + b * 2) #50
print((a + b) * 2) #60
print(a ** 2 + b) #120
print(a // 3)  #3
print(a / 3)   #3.33
# Out:
# 50
# 60
# 120
# 3
# 3.3333333333333335

# %% [markdown]
# Electricity Example

# %%
units = 150
unit_price = 7.5

total_bill = units * unit_price
gst = total_bill * 0.18
final_bill = total_bill + gst
print("Total Bill:",final_bill)
# Out:
# Total Bill: 1327.5

# %%
programming_languages = ["Python","C++","JavaScript","Rust"]
print(programming_languages)

if("Java" in programming_languages):
    print("Java Exists")
else:
    print("Java does not exist")
    
    
if("Python" in programming_languages):
    print("Python Exists")  
else:
    print("Python does not exist")
# Out:
# ['Python', 'C++', 'JavaScript', 'Rust']
# Java does not exist
# Python Exists

# %%
student_roll_no = 26
print(student_roll_no)
print(type(student_roll_no))
float_roll_no = float(student_roll_no)
print(float_roll_no)
print(type(float_roll_no))

string_roll_no = str(student_roll_no)
print(string_roll_no)
print(type(string_roll_no))

int_roll_no = int(float_roll_no)
print(int_roll_no)
print(type(int_roll_no))

male = 1
print(male)
bool_male = bool(male)
print(bool_male)
print(type(bool_male))

int_male = int(bool_male)
print(int_male)
print(type(int_male))
# Out:
# 26
# <class 'int'>
# 26.0
# <class 'float'>
# 26
# <class 'str'>
# 26
# <class 'int'>
# 1
# True
# <class 'bool'>
# 1
# <class 'int'>

# %%
a = 10 
a += 5 
a *= 2 
a -= 8 
a /= 4 
print(a)
# Out:
# 5.5

# %%
print(5 == 5.0) 
print(5 is 5.0)
# Out:
# True
# False
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\dell\AppData\Local\Temp\ipykernel_1864\1103251742.py:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 5.0)

# %% [markdown]
# Store Example

# %%
product_name = "Laptops"
product_price = 40000
product_quantity = 5

print(product_name)
print(product_price)

total_price = product_price * product_quantity
final_price = total_price + (total_price * 0.18)
print("Final Price:", final_price)
# Out:
# Laptops
# 40000
# Final Price: 236000.0

# %% [markdown]
# Driving License

# %%
age = 12
nationality = "Indian"

if age >= 18 and nationality == "Indian":
    print("Eligible for Driving License")
else:
    print("Not Eligible for Driving License")
# Out:
# Not Eligible for Driving License

# %%
name = 
print(name)
