# %% [markdown]
# **Write a program to check whether a number is positive, negative, or zero.**

# %%
num = int(input("Enter the number : "))
if num > 0:
    print(num, "Positive Number")
elif num < 0:
    print(num, "Negative Number")
else:
    print(num, "Zero")
# Out:
# 7 Positive Number

# %% [markdown]
# **Write a program to check whether a person is eligible to vote.**

# %%
age = int(input("Enter your age : "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %% [markdown]
# **Write a program to find the largest of two numbers.**

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
if num1>num2:
    print(num1, "is greater than", num2)
elif num1<num2:
    print(num1, "is less than", num2)
else:
    print(num1, "is equal to", num2)
# Out:
# 70 is greater than 30

# %% [markdown]
# **Write a program to find the largest of three numbers using if-elif-else.**

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
num3 = int(input("Enter third number : "))
if num1 > num2 and num1 > num3:
    print(num1, "first is the greatest number.")
elif num2 > num1 and num2 > num3:
    print(num2, "second is the greatest number.")
else:
    print(num3, "third is the greatest number.")
# Out:
# 30 is the greatest number.

# %% [markdown]
# **Write a program to check whether a student has passed or failed. (Passing Marks = 35)**

# %%
student_marks = int(input("Enter your marks : "))
if student_marks >= 90:
    print("Grade A+")
elif student_marks >= 80:
    print("Grade A")
elif student_marks >= 60:
    print("Grade B")
elif student_marks >= 35:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade C

# %% [markdown]
# **Create a simple login system.**

# %%
username = input("Enter your username : ")
password = input("Enter your password : ")
if username == "admin" and password == "admin123":
    print("Login successful")
elif username == "admin" and password != "admin123":
    print("Incorrect password")
elif username != "admin" and password == "admin123":
    print("Incorrect username")
else:
    print("Incorrect username and password")
# Out:
# Login successful

# %% [markdown]
# **Write a program to determine whether a year is a Leap Year**

# %%
year = float(input("Enter the year : "))
if (year%4 ==0):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# 2016.0 is a leap year.

# %% [markdown]
# **Create a simple calculator using match-case.**

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
option = int(input("Enter the operation option (1-Addition, 2-Subtraction, 3-Multiplication, 4-Division) : "))
match option:
    case 1:
        print(num1, "+", num2, "=", num1 + num2)
    case 2:
        print(num1, "-", num2, "=", num1 - num2)
    case 3:
        print(num1, "*", num2, "=", num1 * num2)
    case 4:
        print(num1, "/", num2, "=", num1 / num2)
    case _:
        print("Invalid option")
# Out:
# 23 - 23 = 0

# %% [markdown]
# **Write a program using the Ternary Operator to determine whether a number is Even or Odd.**

# %%
num = int(input("Enter the number : "))
print("Even Number" if num%2 == 0 else "Odd Number")
# Out:
# Even Number
