# %%
name = "Prathamesh"
age = 21
college_name = "G.S.Moze College of Engineering"
city = "Pune"
course_name="AI&DS"
print("My name is", name, "and I am", age, "years old. I study at", college_name, "in", city, "and I am pursuing a course in", course_name)
# Out:
# My name is Prathamesh and I am 21 years old. I study at G.S.Moze College of Engineering in Pune and I am pursuing a course in AI&DS

# %%
student_name= "Prathamesh"
roll_no= 26
branch= "Artificial Intelligence and Data Science"
percentage= 85.5
passed= True

print("Student Name:", student_name)
print("Roll Number:", roll_no)  
print("Branch:", branch)
print("Percentage:", percentage)
# Out:
# Student Name: Prathamesh
# Roll Number: 26
# Branch: Artificial Intelligence and Data Science
# Percentage: 85.5
